# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# import dependences
import pandas as pd
import matplotlib.pyplot as plt
import requests as rq
import json as js
import numpy as np
from scipy.stats import linregress

# import citipy module to find city based on latitude and longtitude
from citipy import citipy

# Google developer API key
from api_keys import g_key, weather_api_key

# %% [markdown]
# ## Generate Cities List

# %%
# latitude and longtitude range to randomly generate lat, lng values
lat_range = (-90, 90)
lon_range = (-180, 180)

#random.seed(lat_range, lon_range)

lats = np.random.uniform(lat_range[0], lat_range[1], size=1200)
lons = np.random.uniform(lon_range[0], lon_range[1], size=1200)

# %%
# zipping lat, lng for looping
lat_lons = zip(lats, lons)
cities = []

# looping to create the cities list with latitude and longtitude values
for lat_lon in lat_lons:
    city = citipy.nearest_city(lat_lon[0], lat_lon[1]).city_name
    
    if city not in cities:
        cities.append(city)
len(cities)
# Out:
# 530

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# set imperial as units
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

# build partial url query
url = f"http://api.openweathermap.org/data/2.5/weather?appid={weather_api_key}&units={units}&q="

# set up lists to store data 
city_name = []
lat = []
lon = []
humidity = []
wind_speed = []
temp_max = []
cloudiness = []
country = []
date = []

counter = 1
setnum = 1
# Loop through the list of cities and perform a request for data on each
print('Beginning Data Retrieval')
for city in cities:
    # print city name
    # build url query including city name
    query_url = f"{url}{city}"
    response = rq.get(query_url).json()
    
    try:
        print(f"Processing Record {counter} of Set {setnum} | {city}")
    
        country.append(response['sys']['country'])
        city_name.append(response['name'])
        lat.append(response['coord']['lat'])
        lon.append(response['coord']['lon'])
        temp_max.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        wind_speed.append(response['wind']['speed'])
        cloudiness.append(response['clouds']['all'])
        date.append(response['dt'])
        
        counter += 1
        
        if counter > 100:
            setnum += 1 # increase the number of set
            counter = 1 # reset counter
    except:
        print(f'Skipping {city}')
        pass
print('Data Retreival Complete')
# Out:
# Beginning Data Retrieval
# Processing Record 1 of Set 1 | sitka
# Processing Record 2 of Set 1 | chapayevka
# Processing Record 3 of Set 1 | kodiak
# Processing Record 4 of Set 1 | bluff
# Processing Record 5 of Set 1 | vaini
# Processing Record 6 of Set 1 | isiolo
# Processing Record 7 of Set 1 | klaksvik
# Processing Record 8 of Set 1 | haines junction
# Processing Record 9 of Set 1 | burnie
# Processing Record 10 of Set 1 | vao
# Processing Record 11 of Set 1 | jamestown
# Processing Record 12 of Set 1 | novikovo
# Processing Record 13 of Set 1 | traverse city
# Processing Record 14 of Set 1 | khatanga
# Processing Record 15 of Set 1 | saint-philippe
# Processing Record 16 of Set 1 | banda aceh
# Processing Record 17 of Set 1 | rikitea
# Processing Record 18 of Set 1 | hilo
# Processing Record 19 of Set 1 | ushuaia
# Processing Record 20 of Set 1 | barentsburg
# Skipping barentsburg
# Processing Record 20 of Set 1 | tieling
# Processing Record 21 of Set 1 | riberalta
# Processing Record 22 of Set 1 | igurusi
# Processing Record 23 of Set 1 | severo-kurilsk
# Processing Record 24 of Set 1 | kaeo
# Processing Record 25 of Set 1 | olafsvik
# Processing Record 26 of Set 1 | egvekinot
# Processing Record 27 of Set 1 | qui nhon
# Processing Record 28 of Set 1 | vila franca do campo
# Processing Record 29 of Set 1 | grand gaube
# Processing Record 47 of Set 2 | tabou
# Processing Record 48 of Set 2 | east london
# Processing Record 49 of Set 2 | kuruman
# Processing Record 50 of Set 2 | tessalit
# Processing Record 51 of Set 2 | rocha
# Processing Record 52 of Set 2 | hithadhoo
# Processing Record 53 of Set 2 | grand centre
# Skipping grand centre
# Processing Record 53 of Set 2 | hambantota
# Processing Record 54 of Set 2 | saskylakh
# Processing Record 55 of Set 2 | srednekolymsk
# Processing Record 56 of Set 2 | kalmunai
# Processing Record 57 of Set 2 | lolua
# Skipping lolua
# Processing Record 57 of Set 2 | san juan del cesar
# Processing Record 58 of Set 2 | sao filipe
# Processing Record 59 of Set 2 | san michele al tagliamento
# Processing Record 60 of Set 2 | samalaeulu
# Skipping samalaeulu
# Processing Record 60 of Set 2 | marcona
# Skipping marcona
# Processing Record 60 of Set 2 | thompson
# Processing Record 61 of Set 2 | ponta do sol
# Processing Record 62 of Set 2 | luderitz
# Processing Record 63 of Set 2 | calatayud
# Processing Record 64 of Set 2 | yanan
# Skipping yanan
# Processing Record 64 of Set 2 | nuevo progreso
# Processing Record 65 of Set 2 | reconquista
# Processing Record 66 of Set 2 | cayenne
# Processing Record 67 of Set 2 | aguas vermelhas
# Processing Record 68 of Set 2 | morondava
# Processing Record 69 of Set 2 | dyurtyuli
# Processing Record 70 of Set 2 | mar del plata
# Processing Record 71 of Set 2 | port-cartier
# Processing Record 72 of Set 2 | qaqortoq
# Processing Record 73 of Set 2 | ostrow mazowiecka
# Processing Record 74 of Set 2 | jinchang
# Processing Record 75 of Set 2 | ahipara
# Processing Record 76 of Set 2 | xinzhou
# Processing Record 77 of Set 2 | balkanabat
# Processing Record 78 of Set 2 | poum
# Processing Record 79 of Set 2 | kirillov
# Processing Record 80 of Set 2 | wahiawa
# Processing Record 81 of Set 2 | nishihara
# Processing Record 82 of Set 2 | beringovskiy
# Processing Record 83 of Set 2 | atar
# Processing Record 84 of Set 2 | urumqi
# Processing Record 85 of Set 2 | geraldton
# Processing Record 86 of Set 2 | norman wells
# Processing Record 87 of Set 2 | tautira
# Processing Record 88 of Set 2 | trinidad
# Processing Record 89 of Set 2 | dumai
# Processing Record 90 of Set 2 | millinocket
# Processing Record 91 of Set 2 | san patricio
# Processing Record 92 of Set 2 | kamenskoye
# Skipping kamenskoye
# Processing Record 92 of Set 2 | bereda
# Processing Record 93 of Set 2 | fairbanks
# Processing Record 94 of Set 2 | klyuchi
# Processing Record 95 of Set 2 | longyearbyen
# Processing Record 96 of Set 2 | clyde river
# Processing Record 97 of Set 2 | antofagasta
# Processing Record 98 of Set 2 | tabialan
# Skipping tabialan
# Processing Record 98 of Set 2 | jacareacanga
# Processing Record 99 of Set 2 | mys shmidta
# Skipping mys shmidta
# Processing Record 99 of Set 2 | verkhnevilyuysk
# Processing Record 100 of Set 2 | ancud
# Processing Record 1 of Set 3 | hobart
# Processing Record 59 of Set 3 | narsaq
# Processing Record 60 of Set 3 | santa catalina
# Processing Record 61 of Set 3 | lisala
# Processing Record 62 of Set 3 | bali
# Processing Record 63 of Set 3 | praia da vitoria
# Processing Record 64 of Set 3 | ayni
# Processing Record 65 of Set 3 | puksoozero
# Processing Record 66 of Set 3 | genhe
# Processing Record 67 of Set 3 | langevag
# Processing Record 68 of Set 3 | baragua
# Processing Record 69 of Set 3 | kathu
# Processing Record 70 of Set 3 | eyl
# Processing Record 71 of Set 3 | nizhneyansk
# Skipping nizhneyansk
# Processing Record 71 of Set 3 | nara
# Processing Record 72 of Set 3 | college
# Processing Record 73 of Set 3 | jeremoabo
# Processing Record 74 of Set 3 | faanui
# Processing Record 75 of Set 3 | ribeira grande
# Processing Record 76 of Set 3 | bambous virieux
# Processing Record 77 of Set 3 | nanortalik
# Processing Record 78 of Set 3 | port hardy
# Processing Record 79 of Set 3 | rio gallegos
# Processing Record 80 of Set 3 | skeldon
# Processing Record 81 of Set 3 | kendari
# Processing Record 82 of Set 3 | nizza monferrato
# Processing Record 83 of Set 3 | byron bay
# Processing Record 84 of Set 3 | cap malheureux
# Processing Record 85 of Set 3 | marsh harbour
# Processing Record 86 of Set 3 | karakendzha
# Skipping karakendzha
# Processing Record 86 of Set 3 | marzuq
# Processing Record 87 of Set 3 | sorada
# Processing Record 88 of Set 3 | gat
# Processing Record 89 of Set 3 | mount isa
# Processing Record 90 of Set 3 | ocho rios
# Processing Record 91 of Set 3 | bastos
# Processing Record 92 of Set 3 | eydhafushi
# Processing Record 93 of Set 3 | port hedland
# Processing Record 94 of Set 3 | nchelenge
# Processing Record 95 of Set 3 | staryy nadym
# Processing Record 96 of Set 3 | imbituba
# Processing Record 97 of Set 3 | guamuchil
# Processing Record 98 of Set 3 | salalah
# Processing Record 99 of Set 3 | mount gambier
# Processing Record 100 of Set 3 | ust-nera
# Processing Record 1 of Set 4 | santa isabel
# Processing Record 2 of Set 4 | hamilton
# Processing Record 3 of Set 4 | bryan
# Processing Record 4 of Set 4 | luwuk
# Processing Record 5 of Set 4 | tiksi
# Processing Record 6 of Set 4 | acopiara
# Processing Record 7 of Set 4 | kushmurun
# Processing Record 8 of Set 4 | mehamn
# Processing Record 9 of Set 4 | gravdal
# Processing Record 10 of Set 4 | weiz
# Processing Record 11 of Set 4 | whitehorse
# Processing Record 12 of Set 4 | opuwo
# Processing Record 13 of Set 4 | whyalla
# Processing Record 14 of Set 4 | weihai
# Processing Record 15 of Set 4 | garner
# Processing Record 16 of Set 4 | mareeba
# Processing Record 17 of Set 4 | belyy yar
# Processing Record 18 of Set 4 | henties bay
# Processing Record 19 of Set 4 | bonthe
# Processing Record 20 of Set 4 | puerto narino
# Processing Record 21 of Set 4 | villa del rosario
# Processing Record 22 of Set 4 | huadian
# Processing Record 23 of Set 4 | santa eulalia del rio
# Skipping santa eulalia del rio
# Processing Record 23 of Set 4 | chokurdakh
# Processing Record 24 of Set 4 | abonnema
# Processing Record 25 of Set 4 | mulchen
# Processing Record 26 of Set 4 | robertsport
# Processing Record 27 of Set 4 | elko
# Processing Record 28 of Set 4 | yellowknife
# Processing Record 29 of Set 4 | puerto baquerizo moreno
# Processing Record 30 of Set 4 | ulladulla
# Processing Record 31 of Set 4 | aromashevo
# Processing Record 32 of Set 4 | vostok
# Processing Record 33 of Set 4 | baft
# Processing Record 34 of Set 4 | piranhas
# Processing Record 35 of Set 4 | keti bandar
# Processing Record 36 of Set 4 | oissel
# Processing Record 37 of Set 4 | daru
# Processing Record 38 of Set 4 | kasongo-lunda
# Processing Record 39 of Set 4 | shinuhayr
# Processing Record 40 of Set 4 | puerto madero
# Processing Record 41 of Set 4 | kuldur
# Processing Record 42 of Set 4 | calhoun
# Processing Record 43 of Set 4 | airai
# Processing Record 44 of Set 4 | chama
# Processing Record 45 of Set 4 | alofi
# Processing Record 46 of Set 4 | ayan
# Processing Record 47 of Set 4 | gornopravdinsk
# Processing Record 48 of Set 4 | bilaspur
# Processing Record 49 of Set 4 | taltal
# Processing Record 50 of Set 4 | peniche
# Processing Record 51 of Set 4 | vaitupu
# Skipping vaitupu
# Processing Record 51 of Set 4 | heihe
# Processing Record 52 of Set 4 | karoi
# Processing Record 53 of Set 4 | bansgaon
# Processing Record 54 of Set 4 | jibuti
# Processing Record 55 of Set 4 | dallas
# Processing Record 56 of Set 4 | thunder bay
# Processing Record 57 of Set 4 | iqaluit
# Processing Record 58 of Set 4 | manokwari
# Processing Record 59 of Set 4 | xining
# Processing Record 60 of Set 4 | ilulissat
# Processing Record 61 of Set 4 | baykit
# Processing Record 62 of Set 4 | green river
# Processing Record 63 of Set 4 | havelock
# Processing Record 64 of Set 4 | bilibino
# Processing Record 65 of Set 4 | rivadavia
# Processing Record 66 of Set 4 | bulolo
# Processing Record 67 of Set 4 | huarmey
# Processing Record 68 of Set 4 | eirunepe
# Processing Record 69 of Set 4 | anloga
# Processing Record 70 of Set 4 | amurzet
# Processing Record 71 of Set 4 | gulshat
# Skipping gulshat
# Processing Record 71 of Set 4 | pedernales
# Processing Record 72 of Set 4 | carmen
# Processing Record 73 of Set 4 | ambon
# Processing Record 74 of Set 4 | miri
# Processing Record 75 of Set 4 | ormara
# Processing Record 76 of Set 4 | porbandar
# Processing Record 77 of Set 4 | bireun
# Processing Record 78 of Set 4 | porto san giorgio
# Processing Record 79 of Set 4 | santa rosa
# Processing Record 80 of Set 4 | uk
# Skipping uk
# Processing Record 80 of Set 4 | caravelas
# Processing Record 81 of Set 4 | lang son
# Processing Record 82 of Set 4 | mana
# Processing Record 83 of Set 4 | aripuana
# Processing Record 84 of Set 4 | acolla
# Processing Record 85 of Set 4 | nguiu
# Skipping nguiu
# Processing Record 85 of Set 4 | acapulco
# Processing Record 86 of Set 4 | soyo
# Processing Record 87 of Set 4 | milingimbi
# Skipping milingimbi
# Processing Record 87 of Set 4 | bure
# Processing Record 88 of Set 4 | padang
# Processing Record 89 of Set 4 | mahanoro
# Processing Record 90 of Set 4 | wewak
# Processing Record 91 of Set 4 | cumaribo
# Skipping cumaribo
# Processing Record 91 of Set 4 | alice springs
# Processing Record 92 of Set 4 | tangshan
# Processing Record 93 of Set 4 | mabaruma
# Processing Record 94 of Set 4 | namatanai
# Processing Record 95 of Set 4 | potgietersrus
# Skipping potgietersrus
# Processing Record 95 of Set 4 | lompoc
# Processing Record 96 of Set 4 | brigantine
# Processing Record 97 of Set 4 | clarence town
# Processing Record 98 of Set 4 | umm kaddadah
# Processing Record 99 of Set 4 | namibe
# Processing Record 100 of Set 4 | artyk
# Skipping artyk
# Processing Record 100 of Set 4 | loiza
# Processing Record 1 of Set 5 | nadym
# Processing Record 2 of Set 5 | alta floresta
# Processing Record 3 of Set 5 | cedar city
# Processing Record 4 of Set 5 | ozgon
# Skipping ozgon
# Processing Record 4 of Set 5 | malartic
# Processing Record 5 of Set 5 | dolinsk
# Processing Record 6 of Set 5 | dong hoi
# Processing Record 7 of Set 5 | kenai
# Processing Record 8 of Set 5 | yenagoa
# Processing Record 9 of Set 5 | aksu
# Processing Record 10 of Set 5 | kabanjahe
# Processing Record 11 of Set 5 | sentyabrskiy
# Skipping sentyabrskiy
# Processing Record 11 of Set 5 | rojhan
# Processing Record 12 of Set 5 | ternate
# Processing Record 13 of Set 5 | jomalig
# Skipping jomalig
# Processing Record 13 of Set 5 | grindavik
# Processing Record 14 of Set 5 | naze
# Processing Record 15 of Set 5 | kazalinsk
# Skipping kazalinsk
# Processing Record 15 of Set 5 | asau
# Processing Record 16 of Set 5 | ji-parana
# Skipping ji-parana
# Processing Record 16 of Set 5 | tari
# Processing Record 17 of Set 5 | boma
# Processing Record 18 of Set 5 | biltine
# Processing Record 19 of Set 5 | hope
# Processing Record 20 of Set 5 | kabalo
# Processing Record 21 of Set 5 | jablah
# Processing Record 22 of Set 5 | penzance
# Processing Record 23 of Set 5 | qasigiannguit
# Processing Record 24 of Set 5 | kharp
# Processing Record 25 of Set 5 | te anau
# Processing Record 26 of Set 5 | ouesso
# Processing Record 27 of Set 5 | bundaberg
# Processing Record 28 of Set 5 | turan
# Processing Record 29 of Set 5 | dutse
# Processing Record 30 of Set 5 | esil
# Processing Record 31 of Set 5 | kegayli
# Skipping kegayli
# Processing Record 31 of Set 5 | grants pass
# Processing Record 32 of Set 5 | krasnoselkup
# Processing Record 33 of Set 5 | pueblo
# Processing Record 34 of Set 5 | jieshi
# Processing Record 35 of Set 5 | nuuk
# Processing Record 36 of Set 5 | hofn
# Processing Record 37 of Set 5 | paso de patria
# Processing Record 38 of Set 5 | port-gentil
# Processing Record 39 of Set 5 | yantal
# Processing Record 40 of Set 5 | havre-saint-pierre
# Processing Record 41 of Set 5 | hendersonville
# Processing Record 42 of Set 5 | birin
# Processing Record 43 of Set 5 | tasbuget
# Skipping tasbuget
# Processing Record 43 of Set 5 | kuhdasht
# Processing Record 44 of Set 5 | mendeleyevsk
# Processing Record 45 of Set 5 | tumut
# Processing Record 46 of Set 5 | dubbo
# Processing Record 47 of Set 5 | bajo baudo
# Skipping bajo baudo
# Processing Record 47 of Set 5 | cleveland
# Processing Record 48 of Set 5 | sakaiminato
# Processing Record 49 of Set 5 | oriximina
# Processing Record 50 of Set 5 | curuguaty
# Processing Record 51 of Set 5 | pedregulho
# Processing Record 52 of Set 5 | tinton falls
# Processing Record 53 of Set 5 | nabire
# Processing Record 54 of Set 5 | saint andrews
# Processing Record 55 of Set 5 | revelstoke
# Processing Record 56 of Set 5 | porto novo
# Processing Record 57 of Set 5 | ituni
# Skipping ituni
# Processing Record 57 of Set 5 | talcahuano
# Processing Record 58 of Set 5 | bonavista
# Processing Record 59 of Set 5 | portland
# Processing Record 60 of Set 5 | ambilobe
# Processing Record 61 of Set 5 | mhasla
# Processing Record 62 of Set 5 | kamiiso
# Processing Record 63 of Set 5 | saint-pierre
# Processing Record 64 of Set 5 | kot addu
# Processing Record 65 of Set 5 | mari-turek
# Processing Record 66 of Set 5 | akyab
# Processing Record 67 of Set 5 | limanowa
# Processing Record 68 of Set 5 | san policarpo
# Processing Record 69 of Set 5 | boguchany
# Processing Record 70 of Set 5 | aklavik
# Processing Record 71 of Set 5 | jimenez
# Processing Record 72 of Set 5 | laguna
# Processing Record 73 of Set 5 | marsabit
# Processing Record 74 of Set 5 | lokosovo
# Processing Record 75 of Set 5 | pestravka
# Processing Record 76 of Set 5 | jiroft
# Skipping jiroft
# Processing Record 76 of Set 5 | toyooka
# Processing Record 77 of Set 5 | newton
# Processing Record 78 of Set 5 | kirchheim
# Processing Record 79 of Set 5 | ruatoria
# Skipping ruatoria
# Processing Record 79 of Set 5 | matay
# Data Retreival Complete

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_data = pd.DataFrame({'City': city_name,
                        'Country': country,
                        'Date': date,
                        'Lat': lat,
                        'Lng': lon,
                        'Max Temp': temp_max,
                        'Humidity': humidity,
                        'Cloudiness': cloudiness,
                        'Wind Speed': wind_speed})

# save to csv file
city_data.to_csv('../output_data/cities.csv', index_label="City_ID")

# %%
city_data.head()
# Out:
#                 City Country        Date    Lat     Lng  Max Temp  Humidity  \
# 0              Sitka      US  1601340918  57.05 -135.33     13.00        71
# 1         Chapayevka      UA  1601340919  47.47   36.35     16.72        55
# 2  Saint Paul Harbor      US  1601340919  57.79 -152.41     13.00        50
# 3              Bluff      NZ  1601340919 -46.60  168.33      3.89        69
# 4              Vaini      TO  1601340919 -21.20 -175.20     26.00        78
#
#    Cloudiness  Wind Speed
# 0          75        3.60
# 1         100        6.55
# 2           1        5.70
# 3          99        8.94
# 4          75        4.10

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
reduced_cities = city_data.loc[city_data['Humidity'] > 100]
if reduced_cities.empty == True:
    print('There is no city with humidity over 100% in the selected dataset.')
    # continue using the city_data dataframe for plotting
else:
    #  Get the indices of cities that have humidity over 100%.
    reduced_cities_indexes = reduced_cities.index
    
    # print out list of index for cities with humidity over 100%
    print(reduced_cities.index)
    
    # Make a new DataFrame equal to the city data to drop all humidity outliers by index.
    clean_city_data = city_data.drop(reduced_cities_indexes, inplace=False)
    clean_city_data.head()
    
    # matching the clean data to the city_data dataframe for ploting
    city_data = clean_city_data
    
    # copy clean_city_data to csv file
    clean_city_data.to_csv("../output_data/clean_city_data.csv", index=True, index_label="City_ID", header=True)
# Out:
# There is no city with humidity over 100% in the selected dataset.

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
import matplotlib.pyplot as plt
plt.scatter(city_data["Lat"], city_data["Max Temp"], marker="o", s=18)
plt.title("City Latitude vs. Temperature (04-01-20)")
plt.ylabel("Max Temperature (C)")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("../Images/MaxTemp_vs_Latitude.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
from datetime import date
plt.scatter(city_data["Lat"], city_data["Humidity"], marker="o", s=18)
plt.title(f"City Latitude vs. Humidity (04-01-20)")
plt.ylabel("Humidity %")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("../Images/MaxTemp_vs_Humidity.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(city_data["Lat"], city_data["Cloudiness"], marker="o", s=18)
plt.title("City Latitude vs. Cloudiness (04-01-20)")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("../Images/MaxTemp_vs_Cloudiness.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(city_data["Lat"], city_data["Wind Speed"], marker="o", s=18)
plt.title("City Latitude vs. Wind Speed (04-01-20)")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("../Images/MaxTemp_vs_WindSpeed.png")
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# generate northern and southern hemisphere data for plotting
northern_hemi = city_data.loc[city_data['Lat'] > 0]
southern_hemi = city_data.loc[city_data['Lat'] < 0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# restoring northern hemisphere latitude to x_values
x_values = nothern_hemi['Lat']

# assigning the Max Temperature to y_values
y_values = nothern_hemi['Max Temp']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
print(f'The r-value is: {rvalue}')
plt.annotate(line_eq,(10,5),fontsize=13,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp (C)')
plt.title('Northern Hemisphere - Max Temp vs. Latitude Linear Regression')

plt.show()
# Out:
# The r-value is: -0.8278935583900215

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = southern_hemi['Lat']
y_values = southern_hemi['Max Temp']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f'The r-value is: {rvalue}')
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-30,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp (C)')
plt.title('Southern Hemisphere - Max Temp vs. Latitude Linear Regression')

plt.show()
# Out:
# The r-value is: 0.7703756769057392

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = nothern_hemi['Lat']
y_values = nothern_hemi['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
print(f'The r-value is: {rvalue}')
plt.annotate(line_eq,(45,16),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression')

plt.show()
# Out:
# The r-value is: 0.05557675973559696

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = southern_hemi['Lat']
y_values = southern_hemi['Max Temp']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f'The r-value is: {rvalue}')
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-26,8),fontsize=13,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression')

plt.show()
# Out:
# The r-value is: 0.7703756769057392

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = northern_hemi['Lat']
y_values = northern_hemi['Cloudiness']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f'The r-value is: {rvalue}')
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(40,30),fontsize=13,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression')
plt.show()
# Out:
# The r-value is: 0.07306735098541355

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = southern_hemi['Lat']
y_values = southern_hemi['Cloudiness']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f'The r-value is: {rvalue}')
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-48,30),fontsize=13,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title('Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression')

plt.show()
# Out:
# The r-value is: 0.025645597896628382

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = northern_hemi['Lat']
y_values = northern_hemi['Wind Speed']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f'The r-value is: {rvalue}')
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(20,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression')

plt.show()
# Out:
# The r-value is: 0.22533209502002147

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = southern_hemi['Lat']
y_values = southern_hemi['Wind Speed']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f'The r-value is: {rvalue}')
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,8),fontsize=13,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression')

plt.show()
# Out:
# The r-value is: -0.23410845699609784
